# %%
import chess.pgn as cp
import numpy as np
import pandas as pd
import matplotlib.patches as mpatches
import matplotlib.pyplot as plt

# %%
#pgn = open("C:\\Users\\ujwal\\data\\stonybrook\\fall2019\\dataScienceFundamentals\\project\\dataset\\data1\\set1.pgn",encoding = "utf-8-sig")

# %%
#df = pd.DataFrame(columns=['Event' ,'Site' ,'White' ,'Black' , 'Result' ,'UTCDate' ,'UTCTime' ,'WhiteElo' ,'BlackElo' ,'WhiteRatingDiff', 'BlackRatingDiff' ,'WhiteTitle' ,'ECO' ,'Opening' ,'TimeControl' ,'Termination', 'Moves'])

# %%
"""i=0
while True:
    game = cp.read_game(pgn)
    i=i+1
    if i%5000 == 0:
        print(i)
    if i>1000000:
        break
    if game is None:
        break
    try:
        df = df.append({'Event': str(game.headers['Event']),'Site': str(game.headers['Site']), 'White': str(game.headers['White']),'Black': str(game.headers['Black']), 'Result': str(game.headers['Result']),'UTCDate': str(game.headers['UTCDate']), 'UTCTime': str(game.headers['UTCTime']),'WhiteElo': str(game.headers['WhiteElo']), 'BlackElo': str(game.headers['BlackElo']), 'WhiteRatingDiff': str('') if (game.headers['WhiteRatingDiff'] is None) else str(game.headers['WhiteRatingDiff']), 'BlackRatingDiff': str(game.headers['BlackRatingDiff']),'ECO': str(game.headers['ECO']), 'Opening': str(game.headers['Opening']),'TimeControl': str(game.headers['TimeControl']),'Termination': str(game.headers['Termination']), 'Moves': str(game.mainline_moves())},ignore_index=True)
    except:
        print(game.headers)
    """
# Out:
# "i=0\nwhile True:\n    game = cp.read_game(pgn)\n    i=i+1\n    if i%5000 == 0:\n        print(i)\n    if i>1000000:\n        break\n    if game is None:\n        break\n    try:\n        df = df.append({'Event': str(game.headers['Event']),'Site': str(game.headers['Site']), 'White': str(game.headers['White']),'Black': str(game.headers['Black']), 'Result': str(game.headers['Result']),'UTCDate': str(game.headers['UTCDate']), 'UTCTime': str(game.headers['UTCTime']),'WhiteElo': str(game.headers['WhiteElo']), 'BlackElo': str(game.headers['BlackElo']), 'WhiteRatingDiff': str('') if (game.headers['WhiteRatingDiff'] is None) else str(game.headers['WhiteRatingDiff']), 'BlackRatingDiff': str(game.headers['BlackRatingDiff']),'ECO': str(game.headers['ECO']), 'Opening': str(game.headers['Opening']),'TimeControl': str(game.headers['TimeControl']),'Termination': str(game.headers['Termination']), 'Moves': str(game.mainline_moves())},ignore_index=True)\n    except:\n        print(game.headers)\n    "
# ...

# %%
#export_csv = df.to_csv (r'C:\Users\ujwal\data\stonybrook\fall2019\dataScienceFundamentals\project\dataset\data191000.csv', index = None, header=True)

# %%
#game = cp.read_game(pgn)
#df = df.append({'Event': str(game.headers['Event']),'Site': str(game.headers['Site']), 'White': str(game.headers['White']),'Black': str(game.headers['Black']), 'Result': str(game.headers['Result']),'UTCDate': str(game.headers['UTCDate']), 'UTCTime': str(game.headers['UTCTime']),'WhiteElo': str(game.headers['WhiteElo']), 'BlackElo': str(game.headers['BlackElo']), 'WhiteRatingDiff': str('') if (game.headers['WhiteRatingDiff'] is None) else str(game.headers['WhiteRatingDiff']), 'BlackRatingDiff': str(game.headers['BlackRatingDiff']),'ECO': str(game.headers['ECO']), 'Opening': str(game.headers['Opening']),'TimeControl': str(game.headers['TimeControl']),'Termination': str(game.headers['Termination']), 'Moves': str(game.mainline_moves())},ignore_index=True)

# %%
df = pd.read_csv("C:\\Users\\ujwal\\data\\stonybrook\\fall2019\\dataScienceFundamentals\\project\\dataset\\export_dataframe.csv")

# %%
df.shape
# Out:
# (109800, 17)

# %%
dfTest = df.copy()

# %%
dfTest.shape
# Out:
# (109800, 17)

# %%
dfTest.head()
# Out:
#                                                Event  \
# 0  Rated Rapid tournament https://lichess.org/tou...
# 1  Rated Blitz tournament https://lichess.org/tou...
# 2  Rated Rapid tournament https://lichess.org/tou...
# 3  Rated Rapid tournament https://lichess.org/tou...
# 4  Rated Rapid tournament https://lichess.org/tou...
#
#                            Site             White          Black Result  \
# 0  https://lichess.org/224ifIC9           Dikeuss     hikarufans    1-0
# 1  https://lichess.org/JRbFTTJX      skankhunt593         Wosito    1-0
# 2  https://lichess.org/TDlv0AjR          strompur    alchemist48    1-0
# 3  https://lichess.org/9HriX6Rx             Geroz     ficher2016    1-0
# 4  https://lichess.org/TECTBYsk  Violin_And_Viola  fasterfourier    1-0
#
#       UTCDate   UTCTime  WhiteElo  BlackElo  WhiteRatingDiff  BlackRatingDiff  \
# 0  2019.09.01  00:00:04      1817      1806                7              -17
# ...

# %%
dfTest['WhiteElo'] = dfTest['WhiteElo'].astype(int)

# %%
dfTest['WhiteElo'].max()
# Out:
# 2901

# %%
bins = [500,1000,1500,2000,2500,3000]
dfTest['eloBins'] = pd.cut(dfTest['WhiteElo'], bins)

# %%
dfTest['eloBins']
# Out:
# 0         (1500, 2000]
# 1         (1000, 1500]
# 2         (2000, 2500]
# 3         (1500, 2000]
# 4         (1500, 2000]
#               ...
# 109795    (1500, 2000]
# 109796    (1500, 2000]
# 109797    (1500, 2000]
# 109798    (1000, 1500]
# 109799    (2000, 2500]
# Name: eloBins, Length: 109800, dtype: category
# Categories (5, interval[int64]): [(500, 1000] < (1000, 1500] < (1500, 2000] < (2000, 2500] < (2500, 3000]]

# %%
top20Openings = dfTest['Opening'].value_counts().head(20).index

# %%
top20Openings
# Out:
# Index(['Modern Defense', 'Van't Kruijs Opening',
#        'Scandinavian Defense: Mieses-Kotroc Variation', 'Sicilian Defense',
#        'Queen's Pawn Game: Mason Attack', 'French Defense: Knight Variation',
#        'Caro-Kann Defense', 'Horwitz Defense', 'Scandinavian Defense',
#        'Owen Defense', 'Sicilian Defense: Bowdler Attack', 'Indian Game',
#        'Sicilian Defense: Old Sicilian', 'Queen's Pawn', 'Hungarian Opening',
#        'Scotch Game', 'Queen's Pawn Game: Chigorin Variation',
#        'Philidor Defense #3', 'Queen's Pawn Game #2', 'Pirc Defense #4'],
#       dtype='object')

# %%
dfTest.groupby('Opening').head()
# Out:
#                                                     Event  \
# 0       Rated Rapid tournament https://lichess.org/tou...
# 1       Rated Blitz tournament https://lichess.org/tou...
# 2       Rated Rapid tournament https://lichess.org/tou...
# 3       Rated Rapid tournament https://lichess.org/tou...
# 4       Rated Rapid tournament https://lichess.org/tou...
# ...                                                   ...
# 109650                                   Rated Blitz game
# 109691                                  Rated Bullet game
# 109718                                  Rated Bullet game
# 109736                                  Rated Bullet game
# 109793                                   Rated Blitz game
#
#                                 Site             White            Black  \
# 0       https://lichess.org/224ifIC9           Dikeuss       hikarufans
# 1       https://lichess.org/JRbFTTJX      skankhunt593           Wosito
# ...

# %%
dfTest = dfTest[dfTest['Opening'].isin(top20Openings)]

# %%
dfTest['Opening'].value_counts()
# Out:
# Modern Defense                                   2134
# Van't Kruijs Opening                             2108
# Scandinavian Defense: Mieses-Kotroc Variation    2062
# Sicilian Defense                                 1602
# Queen's Pawn Game: Mason Attack                  1590
# French Defense: Knight Variation                 1567
# Caro-Kann Defense                                1536
# Horwitz Defense                                  1437
# Scandinavian Defense                             1370
# Owen Defense                                     1308
# Sicilian Defense: Bowdler Attack                 1281
# Indian Game                                      1192
# Sicilian Defense: Old Sicilian                   1168
# Queen's Pawn                                     1135
# Hungarian Opening                                1035
# Scotch Game                                      1004
# Queen's Pawn Game: Chigorin Variation             941
# ...

# %%
openingResultSort = dfTest.groupby(['Opening','Result']).size().reset_index()

# %%
openingResultSort
# Out:
#                                           Opening   Result     0
# 0                               Caro-Kann Defense      0-1   736
# 1                               Caro-Kann Defense      1-0   737
# 2                               Caro-Kann Defense  1/2-1/2    63
# 3                French Defense: Knight Variation      0-1   760
# 4                French Defense: Knight Variation      1-0   753
# 5                French Defense: Knight Variation  1/2-1/2    54
# 6                                 Horwitz Defense      0-1   645
# 7                                 Horwitz Defense      1-0   737
# 8                                 Horwitz Defense  1/2-1/2    55
# 9                               Hungarian Opening      0-1   493
# 10                              Hungarian Opening      1-0   497
# 11                              Hungarian Opening  1/2-1/2    45
# 12                                    Indian Game      0-1   589
# ...

# %%
len(openingResultSort[openingResultSort['Result']=='1/2-1/2'][0].values)
# Out:
# 20

# %%
#openingResultSort[openingResultSort['Result']=='1-0'][0], openingResultSort[openingResultSort['Result']=='0-1'][0]
openingResultSort['Opening'].unique()
# Out:
# array(['Caro-Kann Defense', 'French Defense: Knight Variation',
#        'Horwitz Defense', 'Hungarian Opening', 'Indian Game',
#        'Modern Defense', 'Owen Defense', 'Philidor Defense #3',
#        'Pirc Defense #4', "Queen's Pawn", "Queen's Pawn Game #2",
#        "Queen's Pawn Game: Chigorin Variation",
#        "Queen's Pawn Game: Mason Attack", 'Scandinavian Defense',
#        'Scandinavian Defense: Mieses-Kotroc Variation', 'Scotch Game',
#        'Sicilian Defense', 'Sicilian Defense: Bowdler Attack',
#        'Sicilian Defense: Old Sicilian', "Van't Kruijs Opening"],
#       dtype=object)

# %%
results = pd.DataFrame(columns=['Opening', 'Wins', 'Losses', 'Draws'])
results['Opening'] = openingResultSort['Opening'].unique()
results['Wins'] = pd.Series(openingResultSort[openingResultSort['Result']=='1-0'][0].values)
results['Losses'] = pd.Series(openingResultSort[openingResultSort['Result']=='0-1'][0].values)
results['Draws'] = pd.Series(openingResultSort[openingResultSort['Result']=='1/2-1/2'][0].values)
results
# Out:
#                                           Opening  Wins  Losses  Draws
# 0                               Caro-Kann Defense   737     736     63
# 1                French Defense: Knight Variation   753     760     54
# 2                                 Horwitz Defense   737     645     55
# 3                               Hungarian Opening   497     493     45
# 4                                     Indian Game   559     589     44
# 5                                  Modern Defense  1043    1013     78
# 6                                    Owen Defense   672     585     51
# 7                             Philidor Defense #3   454     411     30
# 8                                 Pirc Defense #4   387     391     27
# 9                                    Queen's Pawn   592     511     32
# 10                           Queen's Pawn Game #2   407     390     40
# 11          Queen's Pawn Game: Chigorin Variation   450     451     40
# ...

# %%
import seaborn as sns

# %%
ax = sns.barplot(x="Opening", y="Wins", data=results)

# %%
results['WinPercent'] = results['Wins']/(results['Wins'] + results['Losses'] + results['Draws'])

# %%
f, ax = plt.subplots(figsize=(10,8))
sns.set(style="whitegrid")
sns.set_color_codes("muted")
ax = sns.barplot(x="WinPercent", y="Opening", data=results, color="b")
ax.set(xlim=(0, 0.7), ylabel="", xlabel="Win Percent")
plt.title('Win Percentage for top 20 Opening Moves')
plt.ylabel('Opening Move')
"""for item in ax.get_xticklabels():
    item.set_rotation(90)"""
# Out:
# 'for item in ax.get_xticklabels():\n    item.set_rotation(90)'

# %%
dfTest['WhiteElo'].describe()
# Out:
# count    27007.000000
# mean      1550.810308
# std        315.505323
# min        600.000000
# 25%       1322.000000
# 50%       1554.000000
# 75%       1769.000000
# max       2846.000000
# Name: WhiteElo, dtype: float64

# %%
r = (dfTest['WhiteElo'].max() - dfTest['WhiteElo'].min())/3
bins = [dfTest['WhiteElo'].min(), dfTest['WhiteElo'].min()+r, dfTest['WhiteElo'].max()-r, dfTest['WhiteElo'].max()]
dfTest['eloBins'] = pd.cut(dfTest['WhiteElo'], bins)

# %%
def addRating(row):
    if row['WhiteElo']<=dfTest['WhiteElo'].min()+r :
        return 'low'
    elif row['WhiteElo']<=dfTest['WhiteElo'].max()-r :
        return 'medium'
    return 'high'

# %%
dfTest['rating'] = dfTest.apply(addRating, axis = 1)

# %%
ratingGroup = dfTest['Opening'].groupby(dfTest['rating']).value_counts()

# %%
ratingsTop5 = ratingGroup.groupby(level = [0]).nlargest(5)
ratingsTop5
# Out:
# rating  rating  Opening
# high    high    Queen's Pawn                                      141
#                 Modern Defense                                    106
#                 Van't Kruijs Opening                              103
#                 Caro-Kann Defense                                 102
#                 Horwitz Defense                                    92
# low     low     Van't Kruijs Opening                              654
#                 Scandinavian Defense: Mieses-Kotroc Variation     518
#                 Scandinavian Defense                              517
#                 Queen's Pawn Game: Mason Attack                   504
#                 Sicilian Defense                                  486
# medium  medium  Modern Defense                                   1579
#                 Scandinavian Defense: Mieses-Kotroc Variation    1474
#                 Van't Kruijs Opening                             1351
# ...

# %%
ratingsTop5.index
# Out:
# MultiIndex([(  'high',   'high', ...),
#             (  'high',   'high', ...),
#             (  'high',   'high', ...),
#             (  'high',   'high', ...),
#             (  'high',   'high', ...),
#             (   'low',    'low', ...),
#             (   'low',    'low', ...),
#             (   'low',    'low', ...),
#             (   'low',    'low', ...),
#             (   'low',    'low', ...),
#             ('medium', 'medium', ...),
#             ('medium', 'medium', ...),
#             ('medium', 'medium', ...),
#             ('medium', 'medium', ...),
#             ('medium', 'medium', ...)],
#            names=['rating', 'rating', 'Opening'])

# %%
indexes = ratingsTop5.index

# %%
groupedMovesCount = [ratingsTop5.values[0:5],ratingsTop5.values[5:10],ratingsTop5.values[10:15]]
ratings15 = [item[1] for item in indexes]
moves15 = [item[2] for item in indexes]
movesCount = ratingsTop5.values

# %%
df1 = pd.DataFrame(movesCount[0:5], index=moves15[0:5])
df1.plot.barh(figsize=(7,4),color='r')
plt.title('Top Five Opening Moves of High Rated Players')
plt.xlabel('Count')
plt.ylabel('Opening Move')
plt.legend(['High'])
df1 = pd.DataFrame(movesCount[5:10], index=moves15[5:10])
df1.plot.barh(figsize=(7,4),color='g')
plt.title('Top Five Opening Moves of Low Rated Players')
plt.xlabel('Count')
plt.ylabel('Opening Move')
plt.legend(['Low'])
df1 = pd.DataFrame(movesCount[10:15], index=moves15[10:15])
df1.plot.barh(figsize=(7,4),color='b')
plt.title('Top Five Opening Moves of Medium Rated Players')
plt.xlabel('Count')
plt.ylabel('Opening Move')
plt.legend(['Medium'])

# %%
ratingMoveCount = pd.DataFrame({'ratings':ratings15,'moves':moves15,'count':movesCount})
ratingMoveCount
# Out:
#    ratings                                          moves  count
# 0     high                                   Queen's Pawn    141
# 1     high                                 Modern Defense    106
# 2     high                           Van't Kruijs Opening    103
# 3     high                              Caro-Kann Defense    102
# 4     high                                Horwitz Defense     92
# 5      low                           Van't Kruijs Opening    654
# 6      low  Scandinavian Defense: Mieses-Kotroc Variation    518
# 7      low                           Scandinavian Defense    517
# 8      low                Queen's Pawn Game: Mason Attack    504
# 9      low                               Sicilian Defense    486
# 10  medium                                 Modern Defense   1579
# 11  medium  Scandinavian Defense: Mieses-Kotroc Variation   1474
# 12  medium                           Van't Kruijs Opening   1351
# ...

# %%
ratingMoveCount.shape
ratingMoveCount.set_index(['ratings', 'moves'], inplace=True)

# %%
ratingMoveCount
# Out:
#                                                        count
# ratings moves
# high    Queen's Pawn                                     141
#         Modern Defense                                   106
#         Van't Kruijs Opening                             103
#         Caro-Kann Defense                                102
#         Horwitz Defense                                   92
# low     Van't Kruijs Opening                             654
#         Scandinavian Defense: Mieses-Kotroc Variation    518
#         Scandinavian Defense                             517
#         Queen's Pawn Game: Mason Attack                  504
#         Sicilian Defense                                 486
# medium  Modern Defense                                  1579
#         Scandinavian Defense: Mieses-Kotroc Variation   1474
#         Van't Kruijs Opening                            1351
#         Caro-Kann Defense                               1212
# ...

# %%
groupedMovesCount
# Out:
# [array([141, 106, 103, 102,  92], dtype=int64),
#  array([654, 518, 517, 504, 486], dtype=int64),
#  array([1579, 1474, 1351, 1212, 1161], dtype=int64)]

# %%
ratingGroup.groupby(level = [0]).nlargest(5)['high']
# Out:
# rating  Opening
# high    Queen's Pawn            141
#         Modern Defense          106
#         Van't Kruijs Opening    103
#         Caro-Kann Defense       102
#         Horwitz Defense          92
# Name: Opening, dtype: int64

# %%
#x =pd.DataFrame({'moves':moves15,'count':movesCount})
x = pd.DataFrame(movesCount, index = moves15, columns=['Count'])

# %%
ax = x.plot(kind='bar', figsize=(12,8), color="rrrrrgggggbbbbb", zorder=2, width=0.85)

# Despine
ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.spines['left'].set_visible(False)
ax.spines['bottom'].set_visible(False)

# Switch off ticks
ax.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

# Draw vertical axis lines
vals = ax.get_xticks()
for tick in vals:
  ax.axvline(x=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

# Set x-axis label
ax.set_xlabel("Opening Move", labelpad=20, weight='bold', size=12)

# Set y-axis label
ax.set_ylabel("Frequency of Opening Move", labelpad=20, weight='bold', size=12)
ax.set_title('Top five Opening moves of players for different ranking categories', pad=20, weight='bold', size=12)

high = mpatches.Patch(color='r', label='High')
low = mpatches.Patch(color='g', label='Low')
medium = mpatches.Patch(color='b', label='Medium')
#plt.title('Top five Opening moves of players for different ranking categories')
plt.legend(handles=[high, low, medium], loc=2)

# Format y-axis label
ax.xaxis.set_major_formatter(StrMethodFormatter('{x:,g}'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-b727ae202628> in <module>
#      29
#      30 # Format y-axis label
# ---> 31 ax.xaxis.set_major_formatter(StrMethodFormatter('{x:,g}'))
#
# NameError: name 'StrMethodFormatter' is not defined

# %%
len(group_labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-4fceb7ca9c08> in <module>
# ----> 1 len(group_labels)
#
# NameError: name 'group_labels' is not defined

# %%
dfTest['Opening'].groupby(dfTest['rating']).value_counts().nlargest(5)
# Out:
# rating  Opening
# medium  Modern Defense                                   1579
#         Scandinavian Defense: Mieses-Kotroc Variation    1474
#         Van't Kruijs Opening                             1351
#         Caro-Kann Defense                                1212
#         French Defense: Knight Variation                 1161
# Name: Opening, dtype: int64

# %%
df.shape
# Out:
# (109800, 17)

# %%
dfTest_plot = dfTest.groupby(['Opening', 'eloBins']).size().reset_index().pivot(columns='Opening', index='eloBins', values=0)

# %%
sns.countplot(x='eloBins', hue = 'Opening', data= dfTest_plot)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-34271140ed24> in <module>
# ----> 1 sns.countplot(x='eloBins', hue = 'Opening', data= dfTest_plot)
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3551                           estimator, ci, n_boot, units,
#    3552                           orient, color, palette, saturation,
# -> 3553                           errcolor, errwidth, capsize, dodge)
#    3554
#    3555     plotter.value_label = "count"
#
# ~\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1605         """Initialize the plotter."""
# ...

# %%
data1 = df.copy()

# %%
data1['Opening'].value_counts().head(20)
# Out:
# Modern Defense                                   2134
# Van't Kruijs Opening                             2108
# Scandinavian Defense: Mieses-Kotroc Variation    2062
# Sicilian Defense                                 1602
# Queen's Pawn Game: Mason Attack                  1590
# French Defense: Knight Variation                 1567
# Caro-Kann Defense                                1536
# Horwitz Defense                                  1437
# Scandinavian Defense                             1370
# Owen Defense                                     1308
# Sicilian Defense: Bowdler Attack                 1281
# Indian Game                                      1192
# Sicilian Defense: Old Sicilian                   1168
# Queen's Pawn                                     1135
# Hungarian Opening                                1035
# Scotch Game                                      1004
# Queen's Pawn Game: Chigorin Variation             941
# ...

# %%
data1['Opening'].nunique()
# Out:
# 2058

# %%
data1['Event'].nunique()
# Out:
# 78

# %%
data1['Event'].value_counts().head(20)
# Out:
# Rated Blitz game                                                   45637
# Rated Bullet game                                                  35699
# Rated Rapid game                                                   11687
# Rated Classical game                                                3696
# Rated Blitz tournament https://lichess.org/tournament/uMVhN7AA       699
# Rated Blitz tournament https://lichess.org/tournament/kSOfOC79       630
# Rated Blitz tournament https://lichess.org/tournament/1kelAP2N       619
# Rated Blitz tournament https://lichess.org/tournament/ljh4apKE       525
# Rated Blitz tournament https://lichess.org/tournament/m555VeJl       490
# Rated Bullet tournament https://lichess.org/tournament/B8T7vn5I      466
# Rated Bullet tournament https://lichess.org/tournament/eLPwJOlP      447
# Rated Blitz tournament https://lichess.org/tournament/BRznvxWm       417
# Rated Blitz tournament https://lichess.org/tournament/HtSTsqah       402
# ...

# %%
#[item in ['Blitz','Bullet','Rapid','Classical'] for item in data1['Event']]
data1.Event
# Out:
# 0         Rated Rapid tournament https://lichess.org/tou...
# 1         Rated Blitz tournament https://lichess.org/tou...
# 2         Rated Rapid tournament https://lichess.org/tou...
# 3         Rated Rapid tournament https://lichess.org/tou...
# 4         Rated Rapid tournament https://lichess.org/tou...
#                                 ...
# 109795                                     Rated Blitz game
# 109796                                    Rated Bullet game
# 109797                                    Rated Bullet game
# 109798                                    Rated Bullet game
# 109799                                    Rated Bullet game
# Name: Event, Length: 109800, dtype: object

# %%
data1['GameType'] = pd.np.where(data1.Event.str.contains("Blitz"), "Blitz",
            pd.np.where(data1.Event.str.contains("Bullet"), "Bullet",
                        pd.np.where(data1.Event.str.contains("Rapid"), "Rapid",
                                    pd.np.where(data1.Event.str.contains("Classical"), "Classical",
                                                "Correspondence"))))

# %%
data1['GameType'].value_counts()
# Out:
# Blitz             52760
# Bullet            40316
# Rapid             12870
# Classical          3709
# Correspondence      145
# Name: GameType, dtype: int64

# %%
data1['WhiteElo'] = data1['WhiteElo'].astype(int)

# %%
data1['rating'] = data1.apply(addRating, axis = 1)

# %%
data1['rating']
# Out:
# 0         medium
# 1         medium
# 2           high
# 3         medium
# 4         medium
#            ...
# 109795    medium
# 109796    medium
# 109797    medium
# 109798       low
# 109799      high
# Name: rating, Length: 109800, dtype: object

# %%
c = data1.groupby(['GameType','rating']).size().values

# %%
typeRatingindices = data1.groupby(['GameType','rating']).size().index

# %%
data1.groupby(['GameType','rating']).size()
# Out:
# GameType        rating
# Blitz           high       3439
#                 low       12739
#                 medium    36582
# Bullet          high       4375
#                 low        7944
#                 medium    27997
# Classical       high         27
#                 low        1118
#                 medium     2564
# Correspondence  high          5
#                 low          13
#                 medium      127
# Rapid           high        175
#                 low        3727
#                 medium     8968
# dtype: int64

# %%
typegroups = [c[0:3],c[3:6],c[6:9],c[9:12],c[12:15]]

# %%
types = ['Blitz','Bullet','Classical','Correspondence','Rapid']
rating_labels = ['low', 'medium', 'high']

df1 = pd.DataFrame(typegroups, index=types)
df1.plot.bar(figsize=(10,8))
plt.title('Type of games played by players in different ranking groups')
plt.xlabel('Game Type')
plt.ylabel('Count')
plt.legend(['High','Low','Medium'])
plt.xticks(rotation='horizontal')
# Out:
# (array([0, 1, 2, 3, 4]), <a list of 5 Text xticklabel objects>)

# %%
print(dfTest['WhiteElo'].min())
print(dfTest['WhiteElo'].min()+r)
print(dfTest['WhiteElo'].max()-r)
print(dfTest['WhiteElo'].max())
# Out:
# 600
# 1348.6666666666665
# 2097.3333333333335
# 2846

# %%
cleanData1 = data1.loc[data1['Opening']!='?']
chessGameType = cleanData1.groupby(['GameType','Opening','rating']).size()

# %%
chessGameType
# Out:
# GameType  Opening                          rating
# Blitz     Alekhine Defense                 high       4
#                                            low       49
#                                            medium    50
#           Alekhine Defense #2              high       2
#                                            low        6
#                                                      ..
# Rapid     Zukertort Opening: The Walrus    low        2
#           Zukertort Opening: Vos Gambit    medium     1
#           Zukertort Opening: Wade Defense  high       1
#                                            low        1
#                                            medium     2
# Length: 9745, dtype: int64

# %%
n, bins, patches = plt.hist(data1['WhiteElo'], 500,facecolor='blue', alpha=0.5)
plt.xlabel('Player ELO Score')
plt.show()

# %% [markdown]
# <h2>Intermediate Report</h2>

# %%
df.shape
# Out:
# (109800, 17)

# %%
#export_csv = df.to_csv (r'C:\Users\ujwal\data\stonybrook\fall2019\dataScienceFundamentals\project\dataset\export_dataframe.csv', index = None, header=True)

# %%
import io

# %%
df.head()
# Out:
#                                                Event  \
# 0  Rated Rapid tournament https://lichess.org/tou...
# 1  Rated Blitz tournament https://lichess.org/tou...
# 2  Rated Rapid tournament https://lichess.org/tou...
# 3  Rated Rapid tournament https://lichess.org/tou...
# 4  Rated Rapid tournament https://lichess.org/tou...
#
#                            Site             White          Black Result  \
# 0  https://lichess.org/224ifIC9           Dikeuss     hikarufans    1-0
# 1  https://lichess.org/JRbFTTJX      skankhunt593         Wosito    1-0
# 2  https://lichess.org/TDlv0AjR          strompur    alchemist48    1-0
# 3  https://lichess.org/9HriX6Rx             Geroz     ficher2016    1-0
# 4  https://lichess.org/TECTBYsk  Violin_And_Viola  fasterfourier    1-0
#
#       UTCDate   UTCTime  WhiteElo  BlackElo  WhiteRatingDiff  BlackRatingDiff  \
# 0  2019.09.01  00:00:04      1817      1806                7              -17
# ...

# %%
data2 = df.copy()

# %%
numRows = data2.shape[0]

# %%
data2['MovesCount'][20500]
# Out:
# ''

# %%
data2["MovesCount"] = ""
data2.head()
# Out:
#                                                Event  \
# 0  Rated Rapid tournament https://lichess.org/tou...
# 1  Rated Blitz tournament https://lichess.org/tou...
# 2  Rated Rapid tournament https://lichess.org/tou...
# 3  Rated Rapid tournament https://lichess.org/tou...
# 4  Rated Rapid tournament https://lichess.org/tou...
#
#                            Site             White          Black Result  \
# 0  https://lichess.org/224ifIC9           Dikeuss     hikarufans    1-0
# 1  https://lichess.org/JRbFTTJX      skankhunt593         Wosito    1-0
# 2  https://lichess.org/TDlv0AjR          strompur    alchemist48    1-0
# 3  https://lichess.org/9HriX6Rx             Geroz     ficher2016    1-0
# 4  https://lichess.org/TECTBYsk  Violin_And_Viola  fasterfourier    1-0
#
#       UTCDate   UTCTime  WhiteElo  BlackElo  WhiteRatingDiff  BlackRatingDiff  \
# 0  2019.09.01  00:00:04      1817      1806                7              -17
# ...

# %%
data2.dtypes
# Out:
# Event               object
# Site                object
# White               object
# Black               object
# Result              object
# UTCDate             object
# UTCTime             object
# WhiteElo             int64
# BlackElo             int64
# WhiteRatingDiff      int64
# BlackRatingDiff      int64
# WhiteTitle         float64
# ECO                 object
# Opening             object
# TimeControl         object
# Termination         object
# Moves               object
# MovesCount          object
# dtype: object

# %%
data2.drop(data2[data2['Termination']=='Abandoned'].index, inplace = True)

# %%
data2.reset_index(inplace=True, drop=True)

# %%
for i in range(0, numRows):
    if data2['Termination'][i] is not None:
        gamestring = io.StringIO(data2['Moves'][i])
        game = cp.read_game(gamestring)
        count=0
        if game is not None:
            for move in game.mainline_moves():
                count=count+1
        data2['MovesCount'][i]=count
# Out:
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-119-6f3d0d313624> in <module>
#       1 for i in range(0, numRows):
#       2     if data2['Termination'][i] is not None:
# ----> 3         gamestring = io.StringIO(data2['Moves'][i])
#       4         game = cp.read_game(gamestring)
#       5         count=0
#
# TypeError: initial_value must be str or None, not float

# %%
data2 = data2.iloc[0:20000,:]

# %%
"""for i in range(0, numRows):
    gamestring = io.StringIO(data2['Moves'][i])
    game = cp.read_game(gamestring)
    count=0
    if game is not None:
        for move in game.mainline_moves():
            count=count+1
    data2['MovesCount'][i]=count"""

# %%
import chess

# %%
data2["WhiteCaptured"] = ""
data2["BlackCaptured"] = ""
data2.head()
# Out:
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                                Event  \
# 0  Rated Rapid tournament https://lichess.org/tou...
# 1  Rated Blitz tournament https://lichess.org/tou...
# ...

# %%
for i in range(0, numRows):
    board = chess.Board()
    if i%5000 == 0:
        print(i)
    gamestring = io.StringIO(data2['Moves'][i])
    game = cp.read_game(gamestring)
    if game is not None:
        for move in game.mainline_moves():
            board.push(move)
    boardMap = board.piece_map()
    blackCount = 0
    whiteCount =0
    for cell in boardMap:
        if str(boardMap[cell]).isupper():
            whiteCount= whiteCount+1
        elif str(boardMap[cell]).islower():
            blackCount = blackCount + 1
    data2['WhiteCaptured'][i] = 16 - whiteCount
    data2['BlackCaptured'][i] = 16 - blackCount
# Out:
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\ujwal\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3326: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# 0
# 5000
# ...

# %%
data2
# Out:
#                                                    Event  \
# 0      Rated Rapid tournament https://lichess.org/tou...
# 1      Rated Blitz tournament https://lichess.org/tou...
# 2      Rated Rapid tournament https://lichess.org/tou...
# 3      Rated Rapid tournament https://lichess.org/tou...
# 4      Rated Rapid tournament https://lichess.org/tou...
# ...                                                  ...
# 19995  Rated Blitz tournament https://lichess.org/tou...
# 19996  Rated Blitz tournament https://lichess.org/tou...
# 19997                                  Rated Bullet game
# 19998                                  Rated Bullet game
# 19999                                  Rated Bullet game
#
#                                Site             White          Black Result  \
# 0      https://lichess.org/224ifIC9           Dikeuss     hikarufans    1-0
# 1      https://lichess.org/JRbFTTJX      skankhunt593         Wosito    1-0
# ...

# %%
data2['EloDifference'] = data2['WhiteElo'].astype(int) - data2['BlackElo'].astype(int)
# Out:
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data2["GameType"] = ""
# Out:
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
"""for i in range(0,numRows):
    data2['GameType'][i] = data2['Event'][i].split(' ', 3)[1]"""

data2['GameType'] = pd.np.where(data2.Event.str.contains("Blitz"), "Blitz",
            pd.np.where(data2.Event.str.contains("Bullet"), "Bullet",
                        pd.np.where(data2.Event.str.contains("Rapid"), "Rapid",
                                    pd.np.where(data2.Event.str.contains("Classical"), "Classical",
                                                "Correspondence"))))
# Out:
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
data2['GameType'].value_counts()
# Out:
# Blitz             9572
# Bullet            7424
# Rapid             2320
# Classical          654
# Correspondence      30
# Name: GameType, dtype: int64

# %%
data2['ECO'].value_counts()
# Out:
# A00    1242
# A40    1004
# B01     930
# C00     815
# D00     805
#        ...
# D61       1
# B89       1
# E22       1
# E05       1
# E53       1
# Name: ECO, Length: 373, dtype: int64

# %%
data2['Moves'][0]
# Out:
# '1. d4 { [%clk 0:05:00] } 1... d5 { [%clk 0:10:00] } 2. Nf3 { [%clk 0:04:59] } 2... Nf6 { [%clk 0:09:56] } 3. g3 { [%clk 0:04:58] } 3... Nc6 { [%clk 0:09:53] } 4. Bg2 { [%clk 0:04:56] } 4... Bf5 { [%clk 0:09:50] } 5. a3 { [%clk 0:04:54] } 5... e5 { [%clk 0:09:44] } 6. dxe5 { [%clk 0:04:51] } 6... Nd7 { [%clk 0:09:40] } 7. Qxd5 { [%clk 0:04:41] } 7... Qe7 { [%clk 0:08:50] } 8. Bf4 { [%clk 0:04:24] } 8... O-O-O { [%clk 0:08:47] } 9. Qb5 { [%clk 0:04:17] } 9... h6 { [%clk 0:08:18] } 10. c4 { [%clk 0:04:06] } 10... g5 { [%clk 0:08:14] } 11. Be3 { [%clk 0:03:59] } 11... a6 { [%clk 0:07:48] } 12. Qb3 { [%clk 0:03:54] } 12... Na5 { [%clk 0:07:19] } 13. Qc3 { [%clk 0:03:46] } 13... Nc6 { [%clk 0:07:03] } 14. b4 { [%clk 0:03:40] } 14... Ncxe5 { [%clk 0:06:57] } 15. O-O { [%clk 0:03:30] } 15... Bg7 { [%clk 0:06:52] } 16. Bd4 { [%clk 0:03:21] } 16... Nxf3+ { [%clk 0:06:16] } 17. exf3 { [%clk 0:03:05] } 17... Ne5 { [%clk 0:06:10] } 18. Re1 { [%clk 0:02:49] } 18... Rhe8 { [%clk 0:05:18] } 19. Ra2
# ...

# %%
data2["RemTimeAftFirstMoveWhite"] = ""
data2["RemTimeAftLastMoveWhite"] = ""
data2["RemTimeAftFirstMoveBlack"] = ""
data2["RemTimeAftLastMoveBlack"] = ""
data2['WhiteTotalEval'] = ''
data2['BlackTotalEval'] = ''
# Out:
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
for i in range(0, len(data2['Moves'])):
    if i%5000 == 0:
        print(i)
    try:
        if data2['Termination'][i]!='Abandoned' and data2['Moves'][i] is not None:
            if 'eval' in data2['Moves'][i]:
                splitres = data2['Moves'][i].split(' } ')
                whiteEvalSum = 0
                blackEvalSum = 0

                for j in range(0, len(splitres)):
                    if j%2 == 0:
                        if '%eval ' in splitres[j]:
                            #if splitres[j].split(']')[0].split('%eval ')[1]=='#1':
                            #    whiteEvalSum = whiteEvalSum + 1
                            if '#' not in splitres[j].split(']')[0].split('%eval ')[1]:
                                whiteEvalSum = whiteEvalSum + float(splitres[j].split(']')[0].split('%eval ')[1])
                    else:
                        if '%eval ' in splitres[j]:
                            #if '%eval ' in splitres[j] and splitres[j].split(']')[0].split('%eval ')[1]=='#1':
                            #    blackEvalSum = blackEvalSum + 1
                            if '#' not in splitres[j].split(']')[0].split('%eval ')[1]:
                                blackEvalSum = blackEvalSum + float(splitres[j].split(']')[0].split('%eval ')[1])
                data2['WhiteTotalEval'][i] = whiteEvalSum
                data2['BlackTotalEval'][i] = blackEvalSum

                if 'clk' in data2['Moves'][i]:
                    data2["RemTimeAftFirstMoveWhite"][i] = splitres[0].split(']')[1].split('%clk ')[1]
                    data2["RemTimeAftFirstMoveBlack"][i] = splitres[1].split(']')[1].split('%clk ')[1]
                    length = len(splitres)
                    if length%2 == 0:
                        if '%eval ' in splitres[length-2]:
                            data2["RemTimeAftLastMoveWhite"][i] = splitres[length-2].split(']')[1].split('%clk ')[1]
                        elif '%eval ' not in splitres[length-2]:
                            data2["RemTimeAftLastMoveWhite"][i] = splitres[length-2].split(']')[0].split('%clk ')[1]
                        if '%eval ' in splitres[length-1]:
                            data2["RemTimeAftLastMoveBlack"][i] = splitres[length-1].split(']')[1].split('%clk ')[1]
                        elif '%eval ' not in splitres[length-1]:
                            data2["RemTimeAftLastMoveBlack"][i] = splitres[length-1].split(']')[0].split('%clk ')[1]
                    else:
                        if '%eval ' in splitres[length-2]:
                            data2["RemTimeAftLastMoveBlack"][i] = splitres[length-2].split(']')[1].split('%clk ')[1]
                        elif '%eval ' not in splitres[length-2]:
                            data2["RemTimeAftLastMoveBlack"][i] = splitres[length-2].split(']')[0].split('%clk ')[1]
                        if '%eval ' in splitres[length-1]:
                            data2["RemTimeAftLastMoveWhite"][i] = splitres[length-1].split(']')[1].split('%clk ')[1]
                        elif '%eval ' not in splitres[length-1]:
                            data2["RemTimeAftLastMoveWhite"][i] = splitres[length-1].split(']')[0].split('%clk ')[1]


            elif 'clk' in data2['Moves'][i]:
                splitres = data2['Moves'][i].split(' } ')
                data2["RemTimeAftFirstMoveWhite"][i] = splitres[0].split("]")[0].split('%clk ')[1]
                data2["RemTimeAftFirstMoveBlack"][i] = splitres[1].split("]")[0].split('%clk ')[1]
                length = len(splitres)
                if length%2 == 0:
                    data2["RemTimeAftLastMoveWhite"][i] = splitres[length-2].split("]")[0].split('%clk ')[1]
                    data2["RemTimeAftLastMoveBlack"][i] = splitres[length-1].split("]")[0].split('%clk ')[1]
                else:
                    data2["RemTimeAftLastMoveBlack"][i] = splitres[length-2].split("]")[0].split('%clk ')[1]
                    data2["RemTimeAftLastMoveWhite"][i] = splitres[length-1].split("]")[0].split('%clk ')[1]
    except:
        print(i)
# Out:
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:53: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
data2['WhiteTotalEval'].notnull().count()
# Out:
# 20000

# %%
data2.head()
# Out:
#                                                Event  \
# 0  Rated Rapid tournament https://lichess.org/tou...
# 1  Rated Blitz tournament https://lichess.org/tou...
# 2  Rated Rapid tournament https://lichess.org/tou...
# 3  Rated Rapid tournament https://lichess.org/tou...
# 4  Rated Rapid tournament https://lichess.org/tou...
#
#                            Site             White          Black Result  \
# 0  https://lichess.org/224ifIC9           Dikeuss     hikarufans    1-0
# 1  https://lichess.org/JRbFTTJX      skankhunt593         Wosito    1-0
# 2  https://lichess.org/TDlv0AjR          strompur    alchemist48    1-0
# 3  https://lichess.org/9HriX6Rx             Geroz     ficher2016    1-0
# 4  https://lichess.org/TECTBYsk  Violin_And_Viola  fasterfourier    1-0
#
#       UTCDate   UTCTime  WhiteElo  BlackElo  WhiteRatingDiff  ...  \
# 0  2019.09.01  00:00:04      1817      1806                7  ...
# 1  2019.09.01  00:00:04      1491      1419                6  ...
# ...

# %%
board= chess.Board()
gamestring = io.StringIO(data2['Moves'][126])
game = cp.read_game(gamestring)
for move in game.mainline_moves():
    board.push(move)
board
# Out:
# Board('6k1/pp1R4/6R1/5K1P/2p2P2/2r5/P7/2b5 b - - 2 40')

# %%
data2.columns
# Out:
# Index(['Event', 'Site', 'White', 'Black', 'Result', 'UTCDate', 'UTCTime',
#        'WhiteElo', 'BlackElo', 'WhiteRatingDiff', 'BlackRatingDiff',
#        'WhiteTitle', 'ECO', 'Opening', 'TimeControl', 'Termination', 'Moves',
#        'MovesCount', 'WhiteCaptured', 'BlackCaptured', 'EloDifference',
#        'GameType', 'RemTimeAftFirstMoveWhite', 'RemTimeAftLastMoveWhite',
#        'RemTimeAftFirstMoveBlack', 'RemTimeAftLastMoveBlack', 'WhiteTotalEval',
#        'BlackTotalEval'],
#       dtype='object')

# %%
listCols= ['Result','WhiteRatingDiff','BlackRatingDiff','ECO','TimeControl','Termination','MovesCount','WhiteCaptured',
           'BlackCaptured', 'EloDifference','RemTimeAftFirstMoveWhite', 'RemTimeAftLastMoveWhite',
       'RemTimeAftFirstMoveBlack', 'RemTimeAftLastMoveBlack','WhiteElo', 'BlackElo','GameType']

# %%
trainData = data2[listCols]

# %%
trainData.head(25)
# Out:
#      Result  WhiteRatingDiff  BlackRatingDiff  ECO TimeControl   Termination  \
# 0       1-0                7              -17  D02       600+0        Normal
# 1       1-0                6               -6  B00       180+0  Time forfeit
# 2       1-0                4               -4  E71       600+0        Normal
# 3       1-0               17               -7  B00       600+0        Normal
# 4       1-0                6               -4  C31       600+0        Normal
# 5       1-0                7               -8  C11        60+0  Time forfeit
# 6       1-0                7               -8  C20        60+0        Normal
# 7       1-0                7               -8  A40        60+0  Time forfeit
# 8       0-1              -12                4  C44        60+0        Normal
# 9   1/2-1/2               -3                1  A52       600+0        Normal
# 10      1-0                7               -7  A10        60+0  Time forfeit
# ...

# %%
trainData.dtypes
# Out:
# Result                      object
# WhiteRatingDiff              int64
# BlackRatingDiff              int64
# ECO                         object
# TimeControl                 object
# Termination                 object
# MovesCount                  object
# WhiteCaptured               object
# BlackCaptured               object
# EloDifference                int32
# RemTimeAftFirstMoveWhite    object
# RemTimeAftLastMoveWhite     object
# RemTimeAftFirstMoveBlack    object
# RemTimeAftLastMoveBlack     object
# WhiteElo                     int64
# BlackElo                     int64
# GameType                    object
# dtype: object

# %%
a = (trainData['Result'])

for i in range(0,a.shape[0]):
    if(a[i]=='1/2-1/2'):
        a[i]=2
    elif(a[i]=='0-1' ):
        a[i]=0
    else:
        a[i]=1

a
# Out:
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# 0        1
# 1        1
# ...

# %%
a.value_counts()
trainData['ResultCoded'] = a
# Out:
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
trainData.dtypes
# Out:
# Result                      object
# WhiteRatingDiff              int64
# BlackRatingDiff              int64
# ECO                         object
# TimeControl                 object
# Termination                 object
# MovesCount                  object
# WhiteCaptured               object
# BlackCaptured               object
# EloDifference                int32
# RemTimeAftFirstMoveWhite    object
# RemTimeAftLastMoveWhite     object
# RemTimeAftFirstMoveBlack    object
# RemTimeAftLastMoveBlack     object
# WhiteElo                     int64
# BlackElo                     int64
# GameType                    object
# ResultCoded                 object
# dtype: object

# %%
trainData['BlackRatingDiff']= trainData['BlackRatingDiff'].astype(int)
# Out:
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
trainData['WhiteRatingDiff']= trainData['WhiteRatingDiff'].astype(int)
# Out:
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
trainData['MovesCount']= trainData['MovesCount'].astype(int)
trainData['WhiteCaptured']= trainData['WhiteCaptured'].astype(int)
trainData['BlackCaptured']= trainData['BlackCaptured'].astype(int)
trainData['EloDifference']= trainData['EloDifference'].astype(int)
trainData['WhiteElo']= trainData['WhiteElo'].astype(int)
trainData['BlackElo']= trainData['BlackElo'].astype(int)
trainData['ResultCoded']= trainData['ResultCoded'].astype(int)
# Out:
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
#trainData.drop(trainData[trainData['RemTimeAftFirstMoveWhite']==''].index, inplace = True)
#trainData.drop(trainData[trainData['RemTimeAftLastMoveWhite']==''].index, inplace = True)
#trainData.drop(trainData[trainData['RemTimeAftFirstMoveBlack']==''].index, inplace = True)
#trainData.drop(trainData[trainData['RemTimeAftLastMoveBlack']==''].index, inplace = True)

# %%
trainData.head(20)
# Out:
#    Result  WhiteRatingDiff  BlackRatingDiff  ECO TimeControl   Termination  \
# 0       1                7              -17  D02       600+0        Normal
# 1       1                6               -6  B00       180+0  Time forfeit
# 2       1                4               -4  E71       600+0        Normal
# 3       1               17               -7  B00       600+0        Normal
# 4       1                6               -4  C31       600+0        Normal
# 5       1                7               -8  C11        60+0  Time forfeit
# 6       1                7               -8  C20        60+0        Normal
# 7       1                7               -8  A40        60+0  Time forfeit
# 8       0              -12                4  C44        60+0        Normal
# 9       2               -3                1  A52       600+0        Normal
# 10      1                7               -7  A10        60+0  Time forfeit
# ...

# %%
trainData[trainData['RemTimeAftFirstMoveWhite']==0]
# Out:
# Empty DataFrame
# Columns: [Result, WhiteRatingDiff, BlackRatingDiff, ECO, TimeControl, Termination, MovesCount, WhiteCaptured, BlackCaptured, EloDifference, RemTimeAftFirstMoveWhite, RemTimeAftLastMoveWhite, RemTimeAftFirstMoveBlack, RemTimeAftLastMoveBlack, WhiteElo, BlackElo, GameType, ResultCoded]
# Index: []

# %%
trainData['a1']# = trainData['RemTimeAftLastMoveBlack']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'a1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-160-f340eede500c> in <module>
# ...

# %%
for i in range(0,trainData.shape[0]):
    trainData['a1'][i] = pd.Timedelta(str(trainData['a1'][i])).seconds

# %%
#trainData.reset_index(inplace=True, drop=True)

# %%
for i in range(0,trainData.shape[0]):
    trainData['RemTimeAftFirstMoveWhite'][i] = pd.Timedelta(str(trainData['RemTimeAftFirstMoveWhite'][i])).seconds
    trainData['RemTimeAftLastMoveWhite'][i] = pd.Timedelta(str(trainData['RemTimeAftLastMoveWhite'][i])).seconds
    trainData['RemTimeAftFirstMoveBlack'][i] = pd.Timedelta(str(trainData['RemTimeAftFirstMoveBlack'][i])).seconds
    trainData['RemTimeAftLastMoveBlack'][i] = pd.Timedelta(str(trainData['RemTimeAftLastMoveBlack'][i])).seconds
# Out:
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
from sklearn.preprocessing import LabelEncoder
trainData['ECO'] = LabelEncoder().fit_transform(trainData['ECO'])
trainData['TimeControl'] = LabelEncoder().fit_transform(trainData['TimeControl'])
trainData['Termination'] = LabelEncoder().fit_transform(trainData['Termination'])
trainData['GameType'] = LabelEncoder().fit_transform(trainData['GameType'])
# Out:
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
trainData.columns
# Out:
# Index(['Result', 'WhiteRatingDiff', 'BlackRatingDiff', 'ECO', 'TimeControl',
#        'Termination', 'MovesCount', 'WhiteCaptured', 'BlackCaptured',
#        'EloDifference', 'RemTimeAftFirstMoveWhite', 'RemTimeAftLastMoveWhite',
#        'RemTimeAftFirstMoveBlack', 'RemTimeAftLastMoveBlack', 'WhiteElo',
#        'BlackElo', 'GameType', 'ResultCoded'],
#       dtype='object')

# %%
trainDataWithEvals = data2[['Result', 'WhiteRatingDiff', 'BlackRatingDiff', 'ECO', 'TimeControl',
                           'Termination', 'MovesCount', 'WhiteCaptured', 'BlackCaptured', 'EloDifference',
                            'WhiteElo', 'BlackElo', 'GameType', 
                           'WhiteTotalEval', 'BlackTotalEval']]

# %%
trainDataWithEvals.drop(trainDataWithEvals[trainDataWithEvals['WhiteTotalEval']==''].index, inplace = True)
trainDataWithEvals.drop(trainDataWithEvals[trainDataWithEvals['BlackTotalEval']==''].index, inplace = True)
# Out:
# C:\Users\ujwal\Anaconda3\lib\site-packages\pandas\core\frame.py:4102: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
trainDataWithEvals
# Out:
#       Result  WhiteRatingDiff  BlackRatingDiff  ECO TimeControl   Termination  \
# 83       0-1               -5                6  A04       180+0        Normal
# 123      1-0                7              -16  B30       600+0        Normal
# 135      1-0                4               -4  A01        60+0        Normal
# 198      1-0               12              -12  A84       300+0        Normal
# 204      1-0                7               -7  A04       300+0        Normal
# ...      ...              ...              ...  ...         ...           ...
# 19876    0-1               -7                7  B95       300+0        Normal
# 19909    1-0                9              -10  B50       180+2  Time forfeit
# 19962    1-0                6               -6  D00       120+1        Normal
# 19965    1-0                7               -7  B30       120+1        Normal
# 19973    1-0                8               -8  A65        60+0        Normal
#
# ...

# %%
trainDataWithEvals.reset_index(inplace=True, drop=True)

# %%
a = (trainDataWithEvals['Result'])
for i in range(0,a.shape[0]):
    if(a[i]=='1/2-1/2'):
        a[i]=2
    elif(a[i]=='0-1' ):
        a[i]=0
    else:
        a[i]=1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-167-f5e0a058bfdf> in <module>
#       1 a = (trainDataWithEvals['Result'])
#       2 for i in range(0,a.shape[0]):
# ----> 3     if(a[i]=='1/2-1/2'):
#       4         a[i]=2
#       5     elif(a[i]=='0-1' ):
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#    1066         key = com.apply_if_callable(key, self)
#    1067         try:
# -> 1068             result = self.index.get_value(self, key)
#    1069
#    1070             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4728         k = self._convert_scalar_indexer(k, kind="getitem")
#    4729         try:
# -> 4730             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4731         except KeyError as e1:
# ...

# %%
trainDataWithEvals['ResultCoded'] = pd.np.where(trainDataWithEvals.Result.str.contains("1-0"), "1",
            pd.np.where(trainDataWithEvals.Result.str.contains("0-1"), "0",
                        "2"))
# Out:
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
trainDataWithEvals.dtypes
# Out:
# Result             object
# WhiteRatingDiff     int64
# BlackRatingDiff     int64
# ECO                object
# TimeControl        object
# Termination        object
# MovesCount         object
# WhiteCaptured      object
# BlackCaptured      object
# EloDifference       int32
# WhiteElo            int64
# BlackElo            int64
# GameType           object
# WhiteTotalEval     object
# BlackTotalEval     object
# ResultCoded        object
# dtype: object

# %%
trainDataWithEvals['BlackRatingDiff']= trainDataWithEvals['BlackRatingDiff'].astype(int)
trainDataWithEvals['WhiteRatingDiff']= trainDataWithEvals['WhiteRatingDiff'].astype(int)
trainDataWithEvals['MovesCount']= trainDataWithEvals['MovesCount'].astype(int)
trainDataWithEvals['WhiteCaptured']= trainDataWithEvals['WhiteCaptured'].astype(int)
trainDataWithEvals['BlackCaptured']= trainDataWithEvals['BlackCaptured'].astype(int)
trainDataWithEvals['EloDifference']= trainDataWithEvals['EloDifference'].astype(int)
trainDataWithEvals['WhiteElo']= trainDataWithEvals['WhiteElo'].astype(int)
trainDataWithEvals['BlackElo']= trainDataWithEvals['BlackElo'].astype(int)
trainDataWithEvals['ResultCoded']= trainDataWithEvals['ResultCoded'].astype(int)
# Out:
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
from sklearn.preprocessing import LabelEncoder
trainDataWithEvals['ECO'] = LabelEncoder().fit_transform(trainDataWithEvals['ECO'])
trainDataWithEvals['TimeControl'] = LabelEncoder().fit_transform(trainDataWithEvals['TimeControl'])
trainDataWithEvals['Termination'] = LabelEncoder().fit_transform(trainDataWithEvals['Termination'])
trainDataWithEvals['GameType'] = LabelEncoder().fit_transform(trainDataWithEvals['GameType'])
# Out:
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
trainDataWithEvals['WhiteTotalEval']= trainDataWithEvals['WhiteTotalEval'].astype(float)
trainDataWithEvals['BlackTotalEval']= trainDataWithEvals['BlackTotalEval'].astype(float)
# Out:
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\ujwal\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
trainDataWithEvals
# Out:
#      Result  WhiteRatingDiff  BlackRatingDiff  ECO  TimeControl  Termination  \
# 0       0-1               -5                6    4           13            0
# 1       1-0                7              -16   64           43            0
# 2       1-0                4               -4    1           41            0
# 3       1-0               12              -12   40           22            0
# 4       1-0                7               -7    4           22            0
# ...     ...              ...              ...  ...          ...          ...
# 1078    0-1               -7                7   86           22            0
# 1079    1-0                9              -10   75           14            1
# 1080    1-0                6               -6  142            5            0
# 1081    1-0                7               -7   64            5            0
# 1082    1-0                8               -8   38           41            0
#
# ...

# %%
import seaborn as sns; 
import matplotlib.pyplot as plt
myCols = ['WhiteRatingDiff', 'BlackRatingDiff', 'MovesCount', 'WhiteCaptured', 'BlackCaptured',
         'WhiteElo', 'BlackElo']
r = trainData[myCols].corr(method='pearson',min_periods=1) 
plt.figure(figsize=(10, 6)) 
ax = sns.heatmap(r, vmin=-1, vmax=1, xticklabels=r.columns, 
                      yticklabels=r.columns, cmap='RdBu_r', annot=True, linewidth=0.5)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
# Out:
# [Text(0.5, 0, 'WhiteRatingDiff'),
#  Text(1.5, 0, 'BlackRatingDiff'),
#  Text(2.5, 0, 'MovesCount'),
#  Text(3.5, 0, 'WhiteCaptured'),
#  Text(4.5, 0, 'BlackCaptured'),
#  Text(5.5, 0, 'WhiteElo'),
#  Text(6.5, 0, 'BlackElo')]

# %% [markdown]
# <h2>Model for Game Type Prediction<h2>

# %%
from sklearn.model_selection import train_test_split

trainingSet, testSet = train_test_split(trainData, test_size=0.2)

XLabel = trainingSet['GameType']
XLabel.shape
trainingSet.head()
Xtrain = trainingSet.drop('GameType',axis =1)
Ytest = testSet.drop('GameType', axis =1)

# %%
Xtrain
# Out:
#       Result  WhiteRatingDiff  BlackRatingDiff  ECO  TimeControl  Termination  \
# 588        1               12               -8  271           52            0
# 10599      0               -7                8  104           82            1
# 3649       0               -7                8   72           82            0
# 7963       1               13               -8    0           29            0
# 13984      2                4               -3   98           26            0
# ...      ...              ...              ...  ...          ...          ...
# 12874      0               -8                8  182           29            0
# 13468      0               -9                9  103           26            0
# 8661       2                2               -3   93           26            0
# 9483       0               -4                4   36           75            0
# 7522       1                9              -11  111           26            0
#
# ...

# %%
# Linear Regression Model Creation
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error

lin_reg = LinearRegression()
lin_reg.fit(Xtrain, XLabel)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-187-58946776d468> in <module>
#       5
#       6 lin_reg = LinearRegression()
# ----> 7 lin_reg.fit(Xtrain, XLabel)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     461         n_jobs_ = self.n_jobs
#     462         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 463                          y_numeric=True, multi_output=True)
#     464
#     465         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %%
#predict on test data split
y_test_predictions_lin_reg = lin_reg.predict(Ytest)
# print (len(y_test_predictions_lin_reg))
lin_mse = mean_squared_error(testSet['GameType'], (y_test_predictions_lin_reg))
lin_rmse = np.sqrt(lin_mse)
print(lin_rmse)

# %%
sns.set()
ax = sns.lineplot(x="GameType", y=lin_rmse, data=trainData)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
neigh = KNeighborsClassifier(n_neighbors=5)
neigh.fit(Xtrain, XLabel) 
predicted = neigh.predict(Ytest)
acc = accuracy_score(testSet['GameType'], predicted)
print(acc)

# %%
import collections
collections.Counter(predicted)
#print(predicted.value_counts())

# %%
from sklearn.datasets import make_classification
from sklearn.cross_validation import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, classification_report, confusion_matrix
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import multilabel_confusion_matrix

# %%
print(f1_score(testSet['GameType'], predicted, average='macro'))

print(f1_score(testSet['GameType'], predicted, average='micro') )

print(f1_score(testSet['GameType'], predicted, average='weighted'))

print(f1_score(testSet['GameType'], predicted, average=None))

# %%
print(precision_recall_fscore_support(testSet['GameType'], predicted, average='macro'))

print(precision_recall_fscore_support(testSet['GameType'], predicted, average='micro'))

print(precision_recall_fscore_support(testSet['GameType'], predicted, average='weighted'))

# %%
multilabel_confusion_matrix(testSet['GameType'], predicted)

# %%
# We use a utility to generate artificial classification data.
X, y = make_classification(n_samples=100, n_informative=10, n_classes=3)
sss = StratifiedShuffleSplit(y, n_iter=1, test_size=0.5, random_state=0)
for train_idx, test_idx in sss:
    X_train, X_test, y_train, y_test = X[train_idx], X[test_idx], y[train_idx], y[test_idx]
    svc.fit(X_train, y_train)
    y_pred = svc.predict(X_test)
    print(f1_score(y_test, y_pred, average="macro"))
    print(precision_score(y_test, y_pred, average="macro"))
    print(recall_score(y_test, y_pred, average="macro"))

# %%
XLabel = trainingSet['GameType']
XLabel.shape
trainingSet.head()
Xtrain = trainingSet.copy()
del Xtrain['GameType']
del Xtrain['TimeControl']
del Xtrain['RemTimeAftFirstMoveWhite']
del Xtrain['RemTimeAftLastMoveWhite']
del Xtrain['RemTimeAftFirstMoveBlack']
del Xtrain['RemTimeAftLastMoveBlack']
Ytest = testSet.copy()
del Ytest['GameType']
del Ytest['TimeControl']
del Ytest['RemTimeAftFirstMoveWhite']
del Ytest['RemTimeAftLastMoveWhite']
del Ytest['RemTimeAftFirstMoveBlack']
del Ytest['RemTimeAftLastMoveBlack']

# %%
Xtrain.columns

# %%
lin_reg = LinearRegression()
lin_reg.fit(Xtrain, XLabel)

# %%
#predict on test data split
y_test_predictions_lin_reg = lin_reg.predict(Ytest)
# print (len(y_test_predictions_lin_reg))
lin_mse = mean_squared_error(testSet['GameType'], (y_test_predictions_lin_reg))
lin_rmse = np.sqrt(lin_mse)
print(lin_rmse)

# %%
sns.set()
ax = sns.lineplot(x="GameType", y=lin_rmse, data=trainingSet)

#ax.set_ylim(bottom=0)
#ax.set(ylim=(0, 30))

# %%
testSet['GameType'].value_counts()

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
neigh = KNeighborsClassifier(n_neighbors=5)
neigh.fit(Xtrain, XLabel) 
predicted = neigh.predict(Ytest)
acc = accuracy_score(test['GameType'], predicted)
print(acc)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(random_state=0)
clf.fit(Xtrain, XLabel)
predicted = clf.predict(Ytest)
acc = accuracy_score(test['GameType'], predicted)
print(acc)

# %%
from sklearn import svm
clf = svm.SVC(gamma='scale')
clf.fit(Xtrain, XLabel)
predicted = clf.predict(Ytest)
acc = accuracy_score(test['GameType'], predicted)
print(acc)

# %% [markdown]
# Training with Evals

# %%
trainingSetEvals, testSetEvals = train_test_split(trainDataWithEvals, test_size=0.2)

Ytrain = trainingSetEvals['GameType']
Xtrain = trainingSetEvals.copy()
del Xtrain['GameType']
del Xtrain['TimeControl']

Ytest = testSetEvals['GameType']
Xtest = testSetEvals.copy()
del Xtest['GameType']
del Xtest['TimeControl']

# %%
Xtrain.head()

# %%
neigh = KNeighborsClassifier(n_neighbors=5)
neigh.fit(Xtrain, Ytrain) 
predicted = neigh.predict(Xtest)
acc = accuracy_score(Ytest, predicted)
print(acc)

# %%
clf = DecisionTreeClassifier(random_state=0)
clf.fit(Xtrain, Ytrain)
predicted = clf.predict(Xtest)
acc = accuracy_score(Ytest, predicted)
print(acc)

# %%
clf = svm.SVC(gamma='scale')
clf.fit(Xtrain, Ytrain)
predicted = clf.predict(Xtest)
acc = accuracy_score(Ytest, predicted)
print(acc)

# %%
from sklearn.model_selection import KFold
from sklearn.svm import SVR

# %%
trainDataWithEvals.columns

# %%
X = trainDataWithEvals.loc[:, ['WhiteRatingDiff', 'BlackRatingDiff', 'ECO', 'TimeControl',
       'Termination', 'MovesCount', 'WhiteCaptured', 'BlackCaptured',
       'EloDifference', 'WhiteElo', 'BlackElo', 'WhiteTotalEval',
       'BlackTotalEval', 'ResultCoded']]
y = trainDataWithEvals.loc[:,['GameType']]

# %%
#del X['TimeControl']

# %%
X

# %%
scores = []
best_svr = SVR(kernel='rbf')
cv = KFold(n_splits=5, random_state=42, shuffle=False)
for train_index, test_index in cv.split(X):
    X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index], y.iloc[train_index], y.iloc[test_index]
    best_svr.fit(X_train, y_train)
    scores.append(best_svr.score(X_test, y_test))
    
print(np.mean(scores))

# %% [markdown]
# <h2>White Rating Prediction<h2>

# %%
XLabel = trainingSet['WhiteElo']
XLabel.shape
trainingSet.head()
Xtrain = trainingSet.drop('WhiteElo',axis =1)
Ytest = testSet.drop('WhiteElo', axis =1)

# %%
# Linear Regression Model Creation
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import mean_squared_error

lin_reg = LinearRegression()
lin_reg.fit(Xtrain, XLabel)

# %%
Xtrain.shape

# %%
#predict on test data split
y_test_predictions_lin_reg = lin_reg.predict(Ytest)
# print (len(y_test_predictions_lin_reg))
lin_mse = mean_squared_error(testSet['WhiteElo'], (y_test_predictions_lin_reg))
lin_rmse = np.sqrt(lin_mse)
print(lin_rmse)

# %%
[i for i in range(len(testSet['WhiteElo'])) if (testSet['WhiteElo']>1600 and testSet['WhiteElo']<1800)]

# %%
#plt.plot(testSet['WhiteElo'], y_test_predictions_lin_reg)
#x1 = list(range(1, 21870)
#y1 = testSet['WhiteElo']

a = list(range(len(testSet.index)))  # use this form to create a new column
plt.figure(figsize=(18,18)) 
plt.plot(a[:100], testSet['WhiteElo'][:100])

plt.plot(a[:100], y_test_predictions_lin_reg[:100])

# %%
from sklearn import linear_model
clf = linear_model.Lasso(alpha=0.1)
clf.fit(Xtrain, XLabel)
y_test_predictions_lin_reg = clf.predict(Ytest)

lin_mse = mean_squared_error(testSet['WhiteElo'], (y_test_predictions_lin_reg))
lin_rmse = np.sqrt(lin_mse)
print(lin_rmse)

# %%
from sklearn import linear_model
clf = linear_model.Ridge(alpha=0.1)
clf.fit(Xtrain, XLabel)
y_test_predictions_lin_reg = clf.predict(Ytest)

lin_mse = mean_squared_error(testSet['WhiteElo'], (y_test_predictions_lin_reg))
lin_rmse = np.sqrt(lin_mse)
print(lin_rmse)

# %%
import lightgbm as lgb
d_train = lgb.Dataset(Xtrain, label=XLabel)
params = {}
params['learning_rate'] = 0.003
params['boosting_type'] = 'gbdt'
params['objective'] = 'binary'
params['metric'] = 'binary_logloss'
params['sub_feature'] = 0.5
params['num_leaves'] = 10
params['min_data'] = 50
params['max_depth'] = 10
clf = lgb.train(params, d_train, 100)

y_test_predictions_lin_reg = clf.predict(Ytest)

lin_mse = mean_squared_error(testSet['WhiteElo'], (y_test_predictions_lin_reg))
lin_rmse = np.sqrt(lin_mse)
print(lin_rmse)

# %%
from sklearn.cluster import AgglomerativeClustering, SpectralClustering 
from sklearn.decomposition import PCA

# %%
clusterData = trainData[['TimeControl',
        'RemTimeAftFirstMoveWhite', 'RemTimeAftLastMoveWhite',
       'RemTimeAftFirstMoveBlack', 'RemTimeAftLastMoveBlack','GameType']].copy()
from sklearn.cluster import KMeans
pca = PCA(n_components=2)
pca_Data = pca.fit_transform(clusterData.loc[:, clusterData.columns != 'GameType'])
pca_DataFrame = pd.DataFrame(data = pca_Data, columns = ['PCA_1', 'PCA_2'])
clusterData = clusterData.reset_index()
clusterData['PCA_1'] = pca_DataFrame['PCA_1']
clusterData['PCA_2'] = pca_DataFrame['PCA_2']
labels = KMeans(n_clusters=5).fit_predict(pca_Data)
for label, color in zip(range(5), ['r', 'g', 'b', 'k', 'm']):
    plt.scatter(pca_Data[labels == label, 0], pca_Data[labels == label, 1], c=color)
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
labels = KMeans(n_clusters=5).fit_predict(trainData)
for label, color in zip(range(6), ['r', 'g', 'b', 'k', 'm']):
    plt.scatter(trainData[labels == label, 0], trainData[labels == label, 1], c=color)
plt.show()

# %%
trainingSet

# %%
XLabel = trainingSet['WhiteElo']
XLabel.shape
trainingSet.head()
Xtrain = trainingSet.copy()
del Xtrain['WhiteElo']
del Xtrain['TimeControl']
del Xtrain['RemTimeAftFirstMoveWhite']
del Xtrain['RemTimeAftLastMoveWhite']
del Xtrain['RemTimeAftFirstMoveBlack']
del Xtrain['RemTimeAftLastMoveBlack']
Ytest = testSet.copy()
del Ytest['WhiteElo']
del Ytest['TimeControl']
del Ytest['RemTimeAftFirstMoveWhite']
del Ytest['RemTimeAftLastMoveWhite']
del Ytest['RemTimeAftFirstMoveBlack']
del Ytest['RemTimeAftLastMoveBlack']

# %%
lin_reg = LinearRegression()
lin_reg.fit(Xtrain, XLabel)

# %%
#predict on test data split
y_test_predictions_lin_reg = lin_reg.predict(Ytest)
# print (len(y_test_predictions_lin_reg))
lin_mse = mean_squared_error(testSet['WhiteElo'], (y_test_predictions_lin_reg))
lin_rmse = np.sqrt(lin_mse)
print(lin_rmse)

# %%
clf = linear_model.Lasso(alpha=0.1)
clf.fit(Xtrain, XLabel)
y_test_predictions_lin_reg = clf.predict(Ytest)

lin_mse = mean_squared_error(testSet['WhiteElo'], (y_test_predictions_lin_reg))
lin_rmse = np.sqrt(lin_mse)
print(lin_rmse)

# %%
clf = linear_model.Ridge(alpha=0.1)
clf.fit(Xtrain, XLabel)
y_test_predictions_lin_reg = clf.predict(Ytest)

lin_mse = mean_squared_error(testSet['WhiteElo'], (y_test_predictions_lin_reg))
lin_rmse = np.sqrt(lin_mse)
print(lin_rmse)

# %%
d_train = lgb.Dataset(Xtrain, label=XLabel)
params = {}
params['learning_rate'] = 0.003
params['boosting_type'] = 'gbdt'
params['objective'] = 'binary'
params['metric'] = 'binary_logloss'
params['sub_feature'] = 0.5
params['num_leaves'] = 10
params['min_data'] = 50
params['max_depth'] = 10
clf = lgb.train(params, d_train, 100)

y_test_predictions_lin_reg = clf.predict(Ytest)

lin_mse = mean_squared_error(testSet['WhiteElo'], (y_test_predictions_lin_reg))
lin_rmse = np.sqrt(lin_mse)
print(lin_rmse)

# %%
trainData['WhiteElo'].describe()

# %%
lowRated = trainData.loc[trainData['WhiteElo']<1500]

# %%
#lowRated.reset_index(inplace=True, drop=True)
lowRated

# %%
trainingSet, testSet = train_test_split(lowRated, test_size=0.2)

# %%
trainingSet

# %%
#mediumRated = trainingSet.loc[trainingSet['WhiteElo']<1500]

# %%
lowRa

# %%
XLabel = trainingSet['WhiteElo']
XLabel.shape
trainingSet.head()
Xtrain = trainingSet.copy()
del Xtrain['WhiteElo']
del Xtrain['TimeControl']
del Xtrain['RemTimeAftFirstMoveWhite']
del Xtrain['RemTimeAftLastMoveWhite']
del Xtrain['RemTimeAftFirstMoveBlack']
del Xtrain['RemTimeAftLastMoveBlack']
Ytest = testSet.copy()
del Ytest['WhiteElo']
del Ytest['TimeControl']
del Ytest['RemTimeAftFirstMoveWhite']
del Ytest['RemTimeAftLastMoveWhite']
del Ytest['RemTimeAftFirstMoveBlack']
del Ytest['RemTimeAftLastMoveBlack']

# %%
Ytest

# %%
lin_reg = LinearRegression()
lin_reg.fit(Xtrain, XLabel)

# %%
#predict on test data split
y_test_predictions_lin_reg = lin_reg.predict(Ytest)
# print (len(y_test_predictions_lin_reg))
lin_mse = mean_squared_error(testSet['WhiteElo'], (y_test_predictions_lin_reg))
lin_rmse = np.sqrt(lin_mse)
print(lin_rmse)

# %%
clf = linear_model.Lasso(alpha=0.1)
clf.fit(Xtrain, XLabel)
y_test_predictions_lin_reg = clf.predict(Ytest)

lin_mse = mean_squared_error(testSet['WhiteElo'], (y_test_predictions_lin_reg))
lin_rmse = np.sqrt(lin_mse)
print(lin_rmse)

# %%
clf = linear_model.Ridge(alpha=0.1)
clf.fit(Xtrain, XLabel)
y_test_predictions_lin_reg = clf.predict(Ytest)

lin_mse = mean_squared_error(testSet['WhiteElo'], (y_test_predictions_lin_reg))
lin_rmse = np.sqrt(lin_mse)
print(lin_rmse)

# %%
a = list(range(len(testSet.index)))  # use this form to create a new column
plt.figure(figsize=(10,2.5)) 
plt.plot(a[:100], testSet['WhiteElo'][:100])
plt.legend(['Actual'])
plt.plot(a[:100], y_test_predictions_lin_reg[:100])
plt.legend(['Predicted'])
plt.ylim([600,1800 ])

# %%
ax = sns.lineplot(x="GameType", y=lin_rmse, data=trainData)

# %%
lin_reg = LinearRegression()
lin_reg.fit(Xtrain, XLabel)

#predict on test data 
y_test_predictions_lin_reg = lin_reg.predict(Ytest)
print (len(y_test_predictions_lin_reg))
# lin_mse = mean_squared_error(testSet['SalePrice'], y_test_predictions_lin_reg)
# lin_rmse = np.sqrt(lin_mse)
# print(lin_rmse)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(trainLR,salePriceLR)
predictions = model.predict(testLR)
from sklearn import metrics
    np.sqrt(metrics.mean_squared_error(salePriceTestLR, predictions))

# %%
pd.Timedelta(str(trainData['RemTimeAftLastMoveBlack'][0])).seconds

# %%
trainData['RemTimeAftFirstMoveWhite'].tail(20)

# %%
gamestring = io.StringIO(data2['Moves'][86])
game = cp.read_game(gamestring)
for move in game.mainline_moves():
    print(move)

# %%
df.shape
